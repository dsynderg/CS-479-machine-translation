# %% [markdown]
# <a href="https://colab.research.google.com/github/dsynderg/CS-479-machine-translation/blob/main/nmt_sep_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install OpenNMT-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.8/262.8 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 130.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 79.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 18.3 MB/s eta 0:00:00
# ...

# %%
# !pip install "numpy<2.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 93.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
with open('Dexter_Syndergaard_cleaned_English.txt', 'r', encoding='utf-8') as src_file, \
     open('Dexter_Syndergaard_cleaned_Spanish.txt', 'r', encoding='utf-8') as tgt_file:
    source_lines = src_file.readlines()
    target_lines = tgt_file.readlines()

# Combine line by line
combined = list(zip(source_lines, target_lines))

# %%
# !onmt_build_vocab -config training_dataset.yaml -nsample -1
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-10-02 18:27:05,410 INFO] Counter vocab from 5000 samples.
# [2025-10-02 18:27:05,410 INFO] Build vocab on 5000 transformed examples/corpus.
# [2025-10-02 18:27:05,608 INFO] Counters src: 16547
# [2025-10-02 18:27:05,608 INFO] Counters tgt: 19642
# [2025-10-02 18:27:05,608 WARNING] path /content/example.vocab.src exists, may overwrite...
# [2025-10-02 18:27:05,618 WARNING] path /content/example.vocab.tgt exists, may overwrite...

# %%
# !onmt_train -config training_dataset.yaml
# Out:
# [2025-10-02 18:32:48,868 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2025-10-02 18:32:48,868 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-10-02 18:32:48,868 INFO] Missing transforms field for valid data, set to default: [].
# [2025-10-02 18:32:48,868 INFO] Parsed 2 corpora from -data.
# [2025-10-02 18:32:48,868 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2025-10-02 18:32:48,926 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'the', 'and', 'of', 'to', 'in', 'a']
# [2025-10-02 18:32:48,926 INFO] The decoder start token is: <s>
# [2025-10-02 18:32:48,927 INFO] Building model...
# [2025-10-02 18:32:50,107 INFO] Switching model to float32 for amp/apex_amp
# [2025-10-02 18:32:50,107 INFO] Non quantized layer compute is fp32
# [2025-10-02 18:32:50,446 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
# !onmt_translate -model /content/sample_data/models_step_20000.pt -src /content/src_test.txt -output /content/sample_data/pred_2000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# PRED 1001: <unk> hacer una diferencia en la manera en que estás y en las cosas que hagas y las decisiones que hagas y las <unk>
# PRED SCORE: -0.4110
#
# [2025-10-02 19:26:38,848 INFO]
# SENT 1002: ['Come', 'back', 'during', 'the', 'conference', 'to', 'see', 'if', 'more', 'of', 'your', 'relatives', 'have', '<unk>']
# PRED 1002: <unk> durante la conferencia, para ver si más de tus parientes han <unk>
# PRED SCORE: -0.2708
#
# [2025-10-02 19:26:38,848 INFO]
# SENT 1003: ['<unk>', 'this', 'lesson', 'have', 'information', 'referring', 'to', 'the', '<unk>']
# PRED 1003: <unk> esta lección tiene información <unk> al <unk>
# PRED SCORE: -0.4489
#
# [2025-10-02 19:26:38,849 INFO]
# SENT 1004: ['<unk>', 'Sacred', 'Lives', 'Before', 'the', 'Lord']
# PRED 1004: <unk> la sagrada vida del Señor
# PRED SCORE: -0.3843
#
# [2025-10-02 19:26:38,849 INFO]
# ...
