# %% [markdown]
# <a href="https://colab.research.google.com/github/dsynderg/CS-479-machine-translation/blob/main/word_embedings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U sentence-transformers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# culpa fault
#
# lo siento im sorry
#
# emberazada pregnant
#
# ajedrez Chess
#
# basura trash
#
# control remote
#
# barco boat
#
# cargador charger
#
# maleta suit-case
#
# pelicula movie

# %%
wordspanish = ['culpa',"lo siento",'embarazada','ajedrez','basura','control','barco','cargador','maleta','pelicula','tu madre']

# %%
wordenglish =['fault',"I'm sorry",'pregnant','Chess','trash','remote','boat','charger','suitcase','flim',"your mom"]

# %%
both = wordspanish+wordenglish
print(both)
# Out:
# ['culpa', 'lo siento', 'embarazada', 'ajedrez', 'basura', 'control', 'barco', 'cargador', 'maleta', 'pelicula', 'fault', "I'm sorry", 'pregnant', 'Chess', 'trash', 'remote', 'boat', 'charger', 'suitcase', 'movie']

# %%
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v2')
embeddings_Spanish = model.encode(wordspanish)
embeddings_english = model.encode(wordenglish)

# %%
similarities = model.similarity(embeddings_Spanish, embeddings_english)

# %%
print(embeddings_Spanish)
# Out:
# [[ 0.02028137 -0.03623249 -0.04634648 ... -0.00738313  0.05944874
#   -0.06675573]
#  [ 0.03078182 -0.0334086  -0.03253333 ... -0.02885351 -0.02102752
#   -0.01821184]
#  [ 0.00511356  0.00905525 -0.02689363 ... -0.00495063  0.00462571
#   -0.02890204]
#  ...
#  [-0.012802   -0.06325266 -0.03506858 ...  0.00291751  0.04185191
#   -0.01095183]
#  [-0.00412194 -0.00262269 -0.02352498 ...  0.01865063  0.03143998
#    0.01139717]
#  [ 0.01752229  0.00456624 -0.01347818 ... -0.03477604  0.0196612
#    0.00122122]]

# %%
plt.figure(figsize=(10,10))
ax = sns.heatmap(similarities, xticklabels=wordspanish, yticklabels=wordenglish, annot=True)

# Move x-axis tick labels to the top
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

# Rotate y-axis tick labels if needed
plt.xticks(rotation=45, ha='left')

plt.show()
